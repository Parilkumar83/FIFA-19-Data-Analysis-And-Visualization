# %% [markdown]
# # Fifa 19 Data Analysis and Visualization

# %% [markdown]
# ## 1.Importing Important Libreries and Loading the Dataset

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_column', 500)

# %%
df = pd.read_csv('dataset.csv')

# %%
df.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %% [markdown]
# ##  2.Dataset General Analysis

# %%
df.shape
# Out:
# (18207, 89)

# %%
df.head().T
# Out:
#                                                                        0  \
# Unnamed: 0                                                             0
# ID                                                                158023
# Name                                                            L. Messi
# Age                                                                   31
# Photo                     https://cdn.sofifa.org/players/4/19/158023.png
# Nationality                                                    Argentina
# Flag                                 https://cdn.sofifa.org/flags/52.png
# Overall                                                               94
# Potential                                                             94
# Club                                                        FC Barcelona
# Club Logo                   https://cdn.sofifa.org/teams/2/light/241.png
# Value                                                            €110.5M
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag',
#        'Overall', 'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 89 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                18207 non-null  int64
#  1   ID                        18207 non-null  int64
#  2   Name                      18207 non-null  object
#  3   Age                       18207 non-null  int64
#  4   Photo                     18207 non-null  object
#  5   Nationality               18207 non-null  object
#  6   Flag                      18207 non-null  object
#  7   Overall                   18207 non-null  int64
#  8   Potential                 18207 non-null  int64
#  9   Club                      17966 non-null  object
#  10  Club Logo                 18207 non-null  object
#  11  Value                     18207 non-null  object
#  12  Wage                      18207 non-null  object
# ...

# %%
df.describe().T
# Out:
#                             count           mean           std    min  \
# Unnamed: 0                18207.0    9103.000000   5256.052511    0.0
# ID                        18207.0  214298.338606  29965.244204   16.0
# Age                       18207.0      25.122206      4.669943   16.0
# Overall                   18207.0      66.238699      6.908930   46.0
# Potential                 18207.0      71.307299      6.136496   48.0
# Special                   18207.0    1597.809908    272.586016  731.0
# International Reputation  18159.0       1.113222      0.394031    1.0
# Weak Foot                 18159.0       2.947299      0.660456    1.0
# Skill Moves               18159.0       2.361308      0.756164    1.0
# Jersey Number             18147.0      19.546096     15.947765    1.0
# Crossing                  18159.0      49.734181     18.364524    5.0
# Finishing                 18159.0      45.550911     19.525820    2.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 89 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                18207 non-null  int64
#  1   ID                        18207 non-null  int64
#  2   Name                      18207 non-null  object
#  3   Age                       18207 non-null  int64
#  4   Photo                     18207 non-null  object
#  5   Nationality               18207 non-null  object
#  6   Flag                      18207 non-null  object
#  7   Overall                   18207 non-null  int64
#  8   Potential                 18207 non-null  int64
#  9   Club                      17966 non-null  object
#  10  Club Logo                 18207 non-null  object
#  11  Value                     18207 non-null  object
#  12  Wage                      18207 non-null  object
# ...

# %% [markdown]
# ## 3.Dealing with Null values and other inappropriate datas

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                      0
# ID                              0
# Name                            0
# Age                             0
# Photo                           0
# Nationality                     0
# Flag                            0
# Overall                         0
# Potential                       0
# Club                          241
# Club Logo                       0
# Value                           0
# Wage                            0
# Special                         0
# Preferred Foot                 48
# International Reputation       48
# Weak Foot                      48
# Skill Moves                    48
# Work Rate                      48
# Body Type                      48
# Real Face                      48
# Position                       60
# Jersey Number                  60
# Joined                       1553
# Loaned From                 16943
# Contract Valid Until          289
# Height                         48
# ...

# %%
if df[df['Height'].isnull()].index.tolist() == df[df['Weight'].isnull()].index.tolist():
    df.drop(df[df['Height'].isnull()].index,inplace =True)
else:
    print("They are different")

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                      0
# ID                              0
# Name                            0
# Age                             0
# Photo                           0
# Nationality                     0
# Flag                            0
# Overall                         0
# Potential                       0
# Club                          241
# Club Logo                       0
# Value                           0
# Wage                            0
# Special                         0
# Preferred Foot                  0
# International Reputation        0
# Weak Foot                       0
# Skill Moves                     0
# Work Rate                       0
# Body Type                       0
# Real Face                       0
# Position                       12
# Jersey Number                  12
# Joined                       1505
# Loaned From                 16895
# Contract Valid Until          241
# Height                          0
# ...

# %%
df.drop(['Unnamed: 0','ID','Photo','Flag','Club Logo','Real Face','Jersey Number','Loaned From'],
          axis=1,inplace=True)

# %%
df['International Reputation'].fillna(df['International Reputation'].mean(), inplace = True) 
df['Skill Moves'].fillna(df['Skill Moves'].mean(), inplace = True)
df['Weak Foot'].fillna(df['Weak Foot'].mean(), inplace = True)
df['Crossing'].fillna(df['Crossing'].mean(), inplace = True)
df['Finishing'].fillna(df['Finishing'].mean(), inplace = True)
df['HeadingAccuracy'].fillna(df['HeadingAccuracy'].mean(), inplace = True)
df['ShortPassing'].fillna(df['ShortPassing'].mean(), inplace = True)
df['Volleys'].fillna(df['Volleys'].mean(), inplace = True)
df['Dribbling'].fillna(df['Dribbling'].mean(), inplace = True) 
df['Curve'].fillna(df['Curve'].mean(), inplace = True) 
df['FKAccuracy'].fillna(df['FKAccuracy'].mean(), inplace = True)
df['LongPassing'].fillna(df['LongPassing'].mean(), inplace = True)
df['BallControl'].fillna(df['BallControl'].mean(), inplace = True)
df['Acceleration'].fillna(df['Acceleration'].mean(), inplace = True)
df['SprintSpeed'].fillna(df['SprintSpeed'].mean(), inplace = True)
df['Agility'].fillna(df['Agility'].mean(), inplace = True)
df['Reactions'].fillna(df['Reactions'].mean(), inplace = True)
df['Balance'].fillna(df['Balance'].mean(), inplace = True)
df['ShotPower'].fillna(df['ShotPower'].mean(), inplace = True)
df['Jumping'].fillna(df['Jumping'].mean(), inplace = True)
df['Stamina'].fillna(df['Stamina'].mean(), inplace = True)
df['Strength'].fillna(df['Strength'].mean(), inplace = True)
df['LongShots'].fillna(df['LongShots'].mean(), inplace = True)
df['Aggression'].fillna(df['Aggression'].mean(), inplace = True)
df['Interceptions'].fillna(df['Interceptions'].mean(), inplace = True)
df['Positioning'].fillna(df['Positioning'].mean(), inplace = True)
df['Vision'].fillna(df['Vision'].mean(), inplace = True)
df['Penalties'].fillna(df['Penalties'].mean(), inplace = True)
df['Composure'].fillna(df['Composure'].mean(), inplace = True)
df['Marking'].fillna(df['Marking'].mean(), inplace = True)
df['StandingTackle'].fillna(df['StandingTackle'].mean(), inplace = True)
df['SlidingTackle'].fillna(df['SlidingTackle'].mean(), inplace = True)
df['GKDiving'].fillna(df['GKDiving'].mean(), inplace = True)
df['GKHandling'].fillna(df['GKHandling'].mean(), inplace = True)
df['GKKicking'].fillna(df['GKKicking'].mean(), inplace = True)
df['GKPositioning'].fillna(df['GKPositioning'].mean(), inplace = True)
df['GKReflexes'].fillna(df['GKReflexes'].mean(), inplace = True)

# %%
df['Club'].fillna('No Club', inplace = True)
df['Position'].fillna('unknown', inplace = True)

# %%
def value_conversion(Value):
    if isinstance(Value,str):
        out = Value.replace('€','')
        if 'M' in out:
            out = float(out.replace('M',''))*1000000
        elif 'K' in Value:
            out = float(out.replace('K',''))*1000
        return float(out)

df['Value'] = df['Value'].apply(lambda x: value_conversion(x))
df['Wage'] = df['Wage'].apply(lambda x: value_conversion(x))
df['Release Clause'] = df['Release Clause'].apply(lambda x: value_conversion(x))
df['Release Clause'].fillna(df['Release Clause'].mean(), inplace = True)

# %%
df['Work Rate'].fillna('Medium/ Medium', inplace = True)

# %%
df['Work Rate'].value_counts()
# Out:
# Medium/ Medium    9810
# High/ Medium      3173
# Medium/ High      1690
# High/ High        1015
# Medium/ Low        850
# High/ Low          699
# Low/ Medium        449
# Low/ High          439
# Low/ Low            34
# Name: Work Rate, dtype: int64

# %%
df['Preferred Foot'].fillna('Right', inplace = True)

# %%
df['Preferred Foot'].value_counts()
# Out:
# Right    13948
# Left      4211
# Name: Preferred Foot, dtype: int64

# %%
df['Body Type'][df['Body Type'] == 'Messi'] = 'Lean'
df['Body Type'][df['Body Type'] == 'C. Ronaldo'] = 'Normal'
df['Body Type'][df['Body Type'] == 'Neymar'] = 'Lean'
df['Body Type'][df['Body Type'] == 'Courtois'] = 'Lean'
df['Body Type'][df['Body Type'] == 'PLAYER_BODY_TYPE_25'] = 'Normal'
df['Body Type'][df['Body Type'] == 'Shaqiri'] = 'Stocky'
df['Body Type'][df['Body Type'] == 'Akinfenwa'] = 'Stocky'
df['Body Type'].fillna('Normal', inplace = True)
# Out:
# C:\Users\PARILK~1\AppData\Local\Temp/ipykernel_1572/4066931111.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Body Type'][df['Body Type'] == 'Messi'] = 'Lean'
# C:\Users\PARILK~1\AppData\Local\Temp/ipykernel_1572/4066931111.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Body Type'][df['Body Type'] == 'C. Ronaldo'] = 'Normal'
# C:\Users\PARILK~1\AppData\Local\Temp/ipykernel_1572/4066931111.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
df['Body Type'].value_counts()
# Out:
# Normal    10597
# Lean       6420
# Stocky     1142
# Name: Body Type, dtype: int64

# %% [markdown]
# ## 4. Age Distribution

# %%
plt.figure(figsize=(14,7))
sns.distplot(x=df['Age'], bins =60)
plt.title('Age distribution')
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## 5.Nationality based Player Distribution

# %%
print("Total No of Countries:", df['Nationality'].nunique())
print(df['Nationality'].value_counts()[0:10])
# Out:
# Total No of Countries: 164
# England        1657
# Germany        1195
# Spain          1071
# Argentina       936
# France          911
# Brazil          825
# Italy           699
# Colombia        616
# Japan           478
# Netherlands     452
# Name: Nationality, dtype: int64

# %%
nation_count = df['Nationality'].value_counts().reset_index().set_index('index').head(20).rename(columns={'Nationality': 'Count'})
nation_count
# Out:
#                      Count
# index
# England               1657
# Germany               1195
# Spain                 1071
# Argentina              936
# France                 911
# Brazil                 825
# Italy                  699
# Colombia               616
# Japan                  478
# Netherlands            452
# Sweden                 396
# China PR               390
# Chile                  388
# Republic of Ireland    368
# Mexico                 365
# United States          353
# Poland                 348
# Norway                 341
# Saudi Arabia           337
# Denmark                335

# %%
fig, ax = plt.subplots(figsize=(14,7))

sns.barplot(nation_count['Count'], nation_count.index)
for i,j in enumerate(nation_count['Count']):
    ax.text(j, i+0.1, str(j))
    

plt.xlabel('Count')
plt.ylabel('Nationality')
plt.title('Nationality count')
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ## 6. Club Based Distribution

# %%
print("Total Number of Clubs:", df['Club'].nunique())
df['Club'].value_counts().head()
# Out:
# Total Number of Clubs: 652
# No Club                241
# Southampton             33
# AS Monaco               33
# TSG 1899 Hoffenheim     33
# Cardiff City            33
# Name: Club, dtype: int64

# %% [markdown]
# ## 7. Player based Analysis

# %%
df.sort_values(by = 'Overall',ascending = False).head(5).loc[:,['Name','Overall']]
# Out:
#                 Name  Overall
# 0           L. Messi       94
# 1  Cristiano Ronaldo       94
# 2          Neymar Jr       92
# 3             De Gea       91
# 4       K. De Bruyne       91

# %%
df.sort_values(by = 'Potential',ascending = False).head(5).loc[:,['Name','Potential']]
# Out:
#                  Name  Potential
# 25          K. Mbappé         95
# 0            L. Messi         94
# 1   Cristiano Ronaldo         94
# 15          P. Dybala         94
# 9            J. Oblak         93

# %%
df.sort_values(by = 'Value',ascending = False).head(5).loc[:,['Name','Value']]
# Out:
#             Name        Value
# 2      Neymar Jr  118500000.0
# 0       L. Messi  110500000.0
# 4   K. De Bruyne  102000000.0
# 5      E. Hazard   93000000.0
# 15     P. Dybala   89000000.0

# %%
df.sort_values(by = 'Wage',ascending = False).head(5).loc[:,['Name','Wage']]
# Out:
#                 Name      Wage
# 0           L. Messi  565000.0
# 7          L. Suárez  455000.0
# 6          L. Modrić  420000.0
# 1  Cristiano Ronaldo  405000.0
# 8       Sergio Ramos  380000.0

# %% [markdown]
# ## 8.Position Based Distribution

# %%
df['Position'].unique()
# Out:
# array(['RF', 'ST', 'LW', 'GK', 'RCM', 'LF', 'RS', 'RCB', 'LCM', 'CB',
#        'LDM', 'CAM', 'CDM', 'LS', 'LCB', 'RM', 'LAM', 'LM', 'LB', 'RDM',
#        'RW', 'CM', 'RB', 'RAM', 'CF', 'RWB', 'LWB', 'unknown'],
#       dtype=object)

# %%
df['Position'].value_counts()
# Out:
# ST         2152
# GK         2025
# CB         1778
# CM         1394
# LB         1322
# RB         1291
# RM         1124
# LM         1095
# CAM         958
# CDM         948
# RCB         662
# LCB         648
# LCM         395
# RCM         391
# LW          381
# RW          370
# RDM         248
# LDM         243
# LS          207
# RS          203
# RWB          87
# LWB          78
# CF           74
# LAM          21
# RAM          21
# RF           16
# LF           15
# unknown      12
# Name: Position, dtype: int64

# %%
Midfielders = ["CAM", "CDM", "CM", "LAM", "LCM", "LM", "LDM", "RAM", "RCM", "RDM", "RM"]
Defence = ["CB", "LB", "LCB", "LWB", "RB", "RCB", "RWB", ]
Forwards= ["CF", "LF", "LS", "LW", "RF", "RS", "RW", "ST"]
Goalkeepers = ['GK']
Not_Specific = ['unknown']
conditions = [(df['Position'].isin(Midfielders)),
              (df['Position'].isin(Defence)),
              (df['Position'].isin(Forwards)),
              (df['Position'].isin(Goalkeepers)),
              (df['Position'].isin(Not_Specific))]
values = ['Midfielders', 'Defence', 'Forwards', 'Goalkeepers','Not Specific']
df['Category'] = np.select(conditions, values)

# %%
df['Category'].value_counts()
# Out:
# Midfielders     6838
# Defence         5866
# Forwards        3418
# Goalkeepers     2025
# Not Specific      12
# Name: Category, dtype: int64

# %%
sns.set_style('darkgrid')
sns.set_context('paper', font_scale=1.4)
cat_count = df['Category'].value_counts()
plt.figure(figsize=(10, 10))
sns.barplot(cat_count.values, cat_count.index, palette="magma")
plt.title('No. of players by position')
plt.ylabel('Position')
plt.xlabel('Players')

plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ## 9. Anlaysis Based on Playing Area

# %%
a = []
Strikers = ["CF","ST","LS","RS"]
Attacking_Winger = ["LF","RF","RW","LW"]
Offensive_Midfielders = ["CAM","CM","LAM","RAM","LM","RM","LCM","RCM"]
Defensive_Midfielders = ["CDM","CM","LDM","RDM","LM","RM","LCM","RCM"]
Centeral_Defenders = ["CB","LCB","RCB"]
Fullbacks = ["LB","RB","LWB","RWB","LCB","RCB"]
Goalkeepers = ["GK"]
Not_Specific = ['unknown']
conditions_2 = [(df['Position'].isin(Strikers)),
              (df['Position'].isin(Attacking_Winger)),
              (df['Position'].isin(Offensive_Midfielders)),
              (df['Position'].isin(Defensive_Midfielders)),
              (df['Position'].isin(Centeral_Defenders)),
              (df['Position'].isin(Fullbacks)),
              (df['Position'].isin(Goalkeepers)),
              (df['Position'].isin(Not_Specific))]

positional_values = ['Strikers', 'Attacking_Wingers', 'Offensive_Midfielders', 'Defensive_Midfielders','Central_Defenders','Fullbacks','Goalkeepers','Not Specific']
df['Positional_Category'] = np.select(conditions_2,positional_values)

# %%
df['Positional_Category'].value_counts()
# Out:
# Offensive_Midfielders    5399
# Central_Defenders        3088
# Fullbacks                2778
# Strikers                 2636
# Goalkeepers              2025
# Defensive_Midfielders    1439
# Attacking_Wingers         782
# Not Specific               12
# Name: Positional_Category, dtype: int64

# %% [markdown]
# ## 10. Best Players in different Playing Areas

# %%
best_striker = df[(df.Finishing >= 85) & (df.Positioning >= 80) & (df.SprintSpeed >= 75) & (df.Acceleration >= 75) & (df.ShotPower >= 85) & (df.Volleys >= 85) & (df.BallControl >= 80) & (df.Overall >= 85) & (df.Potential >= 85) & (df.Positional_Category == 'Strikers')]
print("The Best Strikers are:")
print(best_striker[['Name', 'Club', 'Age', 'Nationality','Overall', 'Position']])
# Out:
# The Best Strikers are:
#                  Name                 Club  Age Nationality  Overall Position
# 1   Cristiano Ronaldo             Juventus   33    Portugal       94       ST
# 7           L. Suárez         FC Barcelona   31     Uruguay       91       RS
# 10     R. Lewandowski    FC Bayern München   29      Poland       90       ST
# 21          E. Cavani  Paris Saint-Germain   31     Uruguay       89       LS
# 23          S. Agüero      Manchester City   30   Argentina       89       ST
# 36            G. Bale          Real Madrid   28       Wales       88       ST
# 48        C. Immobile                Lazio   28       Italy       87       ST

# %%
best_winger = df[(df.Finishing >= 80) & (df.Dribbling >= 85) & (df.Balance >= 85) & (df.BallControl >= 85) & (df.Overall >= 85) & (df.Potential >= 85) & (df.Positional_Category == 'Attacking_Wingers')]
print("The Best Attacking Wingers are:")
print(best_winger[['Name', 'Club', 'Age', 'Nationality','Overall', 'Position']])
# Out:
# The Best Attacking Wingers are:
#           Name               Club  Age Nationality  Overall Position
# 0     L. Messi       FC Barcelona   31   Argentina       94       RF
# 5    E. Hazard            Chelsea   27     Belgium       91       LF
# 15   P. Dybala           Juventus   24   Argentina       89       LF
# 50  D. Mertens             Napoli   31     Belgium       87       RF
# 84   R. Mahrez    Manchester City   27     Algeria       85       RW
# 93  A. Sánchez  Manchester United   29       Chile       85       RW

# %%
best_offensive_midfielder = df[(df.Finishing >= 80) & (df.Dribbling >= 85) & (df.Balance >= 80) & (df.ShortPassing >= 80) & (df.ShotPower >= 75) & (df.BallControl >= 85) & (df.Overall >= 85) & (df.Potential >= 85) & (df.Positional_Category == 'Offensive_Midfielders')]
print("The Best Offensive Midfielders are:")
print(best_offensive_midfielder[['Name', 'Club', 'Age', 'Nationality','Overall', 'Position']])
# Out:
# The Best Offensive Midfielders are:
#                Name                 Club  Age Nationality  Overall Position
# 17     A. Griezmann      Atlético Madrid   27      France       89      CAM
# 25        K. Mbappé  Paris Saint-Germain   19      France       88       RM
# 26         M. Salah            Liverpool   26       Egypt       88       RM
# 61  Roberto Firmino            Liverpool   26      Brazil       86      CAM
# 68          M. Reus    Borussia Dortmund   29     Germany       86       LM
# 80         N. Fekir   Olympique Lyonnais   24      France       85      CAM

# %%
best_defensive_midfielder = df[(df.Strength >= 70) & (df.Aggression >= 80) & (df.Reactions >= 80) & (df.ShortPassing >= 80) & (df.LongPassing >= 75) & (df.Stamina >= 75) & (df.StandingTackle >= 85) & (df.Overall >= 80) & (df.Potential >= 85) & (df.Positional_Category == 'Defensive_Midfielders')]
print("The Best Defensive Midfielders are:")
print(best_defensive_midfielder[['Name', 'Club', 'Age', 'Nationality','Overall', 'Position']])
# Out:
# The Best Defensive Midfielders are:
#                 Name                 Club  Age Nationality  Overall Position
# 14          N. Kanté              Chelsea   27      France       89      LDM
# 20   Sergio Busquets         FC Barcelona   29       Spain       89      CDM
# 27          Casemiro          Real Madrid   26      Brazil       88      CDM
# 75       Fernandinho      Manchester City   33      Brazil       86      CDM
# 118          Fabinho            Liverpool   24      Brazil       84      CDM
# 119       Marquinhos  Paris Saint-Germain   24      Brazil       84      LDM

# %%
best_defenders = df[(df.Strength >= 80) & (df.Aggression >= 80) & (df.Reactions >= 80) & (df.Jumping >= 80) & (df.SlidingTackle >= 80) & (df.Interceptions >= 75) & (df.Stamina >= 70) & (df.StandingTackle >= 85) & (df.Overall >= 85) & (df.Potential >= 85) & (df.Positional_Category == 'Central_Defenders')]
print("The Best Defenders are:")
print(best_defenders[['Name', 'Club', 'Age', 'Nationality','Overall', 'Position']])
# Out:
# The Best Defenders are:
#             Name          Club  Age  Nationality  Overall Position
# 8   Sergio Ramos   Real Madrid   32        Spain       91      RCB
# 42     S. Umtiti  FC Barcelona   24       France       87       CB
# 44  K. Koulibaly        Napoli   27      Senegal       87      LCB
# 59   V. van Dijk     Liverpool   26  Netherlands       86      LCB
# 70    L. Bonucci      Juventus   31        Italy       86      RCB
# 88    K. Manolas          Roma   27       Greece       85      LCB

# %%
best_fullbacks = df[(df.Strength >= 70) & (df.Acceleration >= 70) & (df.Positioning >= 70) & (df.SprintSpeed >= 70) & (df.Dribbling >= 70) & (df.Crossing >= 75) & (df.Stamina >= 80) & (df.StandingTackle >= 70) & (df.Overall >= 80) & (df.Potential >= 85) & (df.Positional_Category == 'Fullbacks')]
print("The Best Fullbacks are:")
print(best_fullbacks[['Name', 'Club', 'Age', 'Nationality','Overall', 'Position']])
# Out:
# The Best Fullbacks are:
#             Name               Club  Age Nationality  Overall Position
# 35       Marcelo        Real Madrid   30      Brazil       88       LB
# 64   Alex Sandro           Juventus   27      Brazil       86       LB
# 85      D. Alaba  FC Bayern München   26     Austria       85       LB
# 106  Filipe Luís    Atlético Madrid   32      Brazil       85       LB
# 352     B. Mendy    Manchester City   23      France       81       LB

# %%
best_goalkeepers = df[(df.GKDiving >= 85) & (df.GKHandling >= 80) & (df.GKKicking >= 75) & (df.GKPositioning >= 80) & (df.GKReflexes >= 85) & (df.Overall >= 85) & (df.Potential >= 85) & (df.Positional_Category == 'Goalkeepers')]
print("The Best Goalkeepers are:")
print(best_goalkeepers[['Name', 'Club', 'Age', 'Nationality','Overall', 'Position']])
# Out:
# The Best Goalkeepers are:
#              Name               Club  Age Nationality  Overall Position
# 3          De Gea  Manchester United   27       Spain       91       GK
# 9        J. Oblak    Atlético Madrid   25    Slovenia       90       GK
# 18  M. ter Stegen       FC Barcelona   26     Germany       89       GK
# 22       M. Neuer  FC Bayern München   32     Germany       89       GK
# 46       K. Navas        Real Madrid   31  Costa Rica       87       GK
# 57        Ederson    Manchester City   24      Brazil       86       GK

# %% [markdown]
# ##  11.Physically best Players

# %%
players_best_physic = df[(df.Agility >= 80) & (df.Strength >= 75) & (df.Balance >= 70) & (df.Acceleration >= 80) & (df.SprintSpeed >= 80) & (df.Jumping >= 80) & (df.Stamina >= 80)]

print("Best Physically Fit Players")
print(players_best_physic[['Name', 'Club', 'Age', 'Nationality', 'Category']])
# Out:
# Best Physically Fit Players
#                     Name                Club  Age Nationality     Category
# 1      Cristiano Ronaldo            Juventus   33    Portugal     Forwards
# 921             F. Fabra        Boca Juniors   27    Colombia      Defence
# 2166         K. Lawrence  New York Red Bulls   25     Jamaica      Defence
# 3272          M. Murillo  New York Red Bulls   22      Panama      Defence
# 5419         R. Fiamozzi               Lecce   25       Italy      Defence
# 7082         D. Vallejos        CD Palestino   28       Chile     Forwards
# 10207         D. Wheeler          Portsmouth   27     England  Midfielders
# 10935           C. Evina        Notts County   26    Cameroon      Defence
# 11270         R. Jackson   Colchester United   27     England      Defence

# %% [markdown]
# ## 12. Best Players according to the specific Attributes

# %%
pr_cols=['Crossing', 'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys',
       'Dribbling', 'Curve', 'FKAccuracy', 'LongPassing', 'BallControl',
       'Acceleration', 'SprintSpeed', 'Agility', 'Reactions', 'Balance',
       'ShotPower', 'Jumping', 'Stamina', 'Strength', 'LongShots',
       'Aggression', 'Interceptions', 'Positioning', 'Vision', 'Penalties',
       'Composure', 'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving',
       'GKHandling', 'GKKicking', 'GKPositioning', 'GKReflexes']
i=0
while i < len(pr_cols):
    print('Best {0} : {1}, Overall Rating: {2}'.format(pr_cols[i],df.loc[df[pr_cols[i]].idxmax()][0],df.loc[df[pr_cols[i]].idxmax()][3]))
    i += 1
# Out:
# Best Crossing : K. De Bruyne, Overall Rating: 91
# Best Finishing : L. Messi, Overall Rating: 94
# Best HeadingAccuracy : Naldo, Overall Rating: 85
# Best ShortPassing : L. Modrić, Overall Rating: 91
# Best Volleys : E. Cavani, Overall Rating: 89
# Best Dribbling : L. Messi, Overall Rating: 94
# Best Curve : Quaresma, Overall Rating: 84
# Best FKAccuracy : L. Messi, Overall Rating: 94
# Best LongPassing : T. Kroos, Overall Rating: 90
# Best BallControl : L. Messi, Overall Rating: 94
# Best Acceleration : Douglas Costa, Overall Rating: 86
# Best SprintSpeed : K. Mbappé, Overall Rating: 88
# Best Agility : Neymar Jr, Overall Rating: 92
# Best Reactions : Cristiano Ronaldo, Overall Rating: 94
# Best Balance : Bernard, Overall Rating: 80
# Best ShotPower : Cristiano Ronaldo, Overall Rating: 94
# Best Jumping : Cristiano Ronaldo, Overall Rating: 94
# Best Stamina : N. Kanté, Overall Rating: 89
# Best Strength : A. Akinfenwa, Overall Rating: 66
# ...
